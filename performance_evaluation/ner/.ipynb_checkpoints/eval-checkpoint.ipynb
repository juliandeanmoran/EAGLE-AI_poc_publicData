# %%
import json
import pandas as pd
from evals import compare_manual_vs_automatic_scores_with_viz, evaluate_f1_between_manual_and_automatic

# %%
manual_df = pd.read_csv("data/manual_curations_subset.csv")
manual_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165 entries, 0 to 164
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                165 non-null    int64
#  1   publication               165 non-null    object
#  2   pmid                      165 non-null    float64
#  3   id                        162 non-null    object
#  4   gene                      165 non-null    object
#  5   inheritance               164 non-null    object
#  6   evidence_type             165 non-null    object
#  7   phenotype_quality         165 non-null    object
#  8   phenotyping_method_notes  164 non-null    object
#  9   genomic_variants          60 non-null     object
#  10  coding_variants           81 non-null     object
#  11  protein_variants          79 non-null     object
#  12  score_justification       165 non-null    object
#  13  score_range               162 non-null    object
#  14  initial_score             165 non-null    float64
#  15  final_score               165 non-null    float64
# dtypes: float64(3), int64(1), object(12)
# memory usage: 20.8+ KB

# %%
manual_df.sample(3)
# Out:
#      Unnamed: 0                                        publication  \
# 162         254  De Bona C, et al. (2000): Preserved speech var...
# 10           24  Dai Y et al. (2022): Expansion of Clinical and...
# 140         230  Moog U, et al. (2003):  Neurodevelopmental dis...
#
#            pmid                                                 id   gene  \
# 162  10854091.0  Case 109 (Detailed clinical information was pr...  MECP2
# 10   35392274.0                                           Female 8  DDX3X
# 140  12615169.0                                     Single proband  MECP2
#
#                                            inheritance  \
# 162  : likely de novo (possibility of germline mosa...
# 10                                           : de novo
# 140                                          : de novo
#
#                   evidence_type               phenotype_quality  \
# 162          Variant is de novo    High Confidence in Phenotype
# 10   Variant is de novomissense     Low Confidence in Phenotype
# 140  Variant is de novomissense  Medium Confidence in Phenotype
#
#                               phenotyping_method_notes genomic_variants  \
# 162  ASD: According to Zappella et al. (1998) PMID:...              NaN
# 10   ASD: The Social Communication Questionnaire (S...   g.41202557dupT
# 140  ASD: Conventional diagnosis of ASD was not det...              NaN
#
#     coding_variants protein_variants  \
# 162             NaN              NaN
# 10         c.632dup         p.I211fs
# 140             NaN              NaN
#
#                                    score_justification score_range  \
# 162  Default score downgraded for genotypic evidenc...       0-2.5
# 10   Default score downgraded for phenotypic eviden...         0-1
# 140  Default score downgraded for genotypic and phe...         0-1
#
#      initial_score  final_score
# 162            2.0         1.25
# 10             0.0         0.25
# 140            0.0         0.15

# %%
#extracted_cases_finetune

with open("data/extracted_cases_converted_NER_phenotype_scored.json") as f:
    eagle_ai_extractions = json.loads(f.read())

# %%
results = compare_manual_vs_automatic_scores_with_viz(manual_df=manual_df, auto_extractions=eagle_ai_extractions)
# Out:
# ================================================================================
# ENHANCED SCORE VERIFICATION SUMMARY
# (Gene matching REQUIRED - only cases with matching genes are included)
# (NOT SCORED cases are excluded entirely from comparison)
# ================================================================================
# Total cases processed: 76
# Publications with matches: 76
# Cases with matches: 76
# Exact score matches: 51
# Overall matching rate: 100.0%
# Exact match rate (of matched): 67.1%
#
# Publication Match Types:
#   - TITLE_AUTHOR_HIGH: 72
#   - TITLE_HIGH: 4
#
# Score Match Types:
#   - EXACT_MATCH: 51
#   - SIGNIFICANT_DIFFERENCE: 14
#   - CLOSE_MATCH: 11
#
# Score Differences:
#   - Average absolute difference: 0.212
#   - Median absolute difference: 0.000
#   - Standard deviation: 0.399
#   - Min/Max difference: 0.000 / 1.650
#
# Case Matching Confidence:
#   - Average confidence: 0.692
#   - High confidence (≥0.8): 27
#   - Medium confidence (≥0.5): 76
#   - Low confidence (<0.5): 0
#
# ================================================================================
#
# ============================================================
# CREATING SCORE COMPARISON VISUALIZATIONS
# ============================================================
# Creating comprehensive score comparison visualizations...
# Visualization complete!

# %%
results.sample(5)
# Out:
#     publication_index                         manual_dataset_publication  \
# 58                 59  Carney RM, et al. (2003): Identification of Me...
# 15                 16  Kim SJ, Cook EHJ (2000):  Novel de novo nonsen...
# 74                 76  Noda S, et al. (2021): Duchenne Muscular Dystr...
# 1                   2  Piton A, et al. (2011): Systematic resequencin...
# 27                 29  Olson HE, et al. (2015): Mutations in epilepsy...
#
#                               auto_extraction_dataset  case_index  \
# 58  Carney RM, et al. - Identification of MeCP2 Mu...           0
# 15  Kim S, et al. - Novel de novo Nonsense Mutatio...           0
# 74  Noda S, et al. - Duchenne Muscular Dystrophy S...           0
# 1   Piton A, et al. - Systematic resequencing of X...           0
# 27  Olson HE, et al. - Mutations in Epilepsy and I...           0
#
#    manual_case_id automatic_case_id manual_gene automatic_gene  manual_score  \
# 58      Patient 1         Patient 1       MECP2          MECP2          0.75
# 15    Single case          case_001       MECP2          MECP2          0.50
# 74    Case report          case_001         DMD            DMD          0.50
# 1             NaN          case_003       MECP2          MECP2          0.25
# 27      Patient 4         Patient 4       MECP2          MECP2          1.25
#
#     automatic_score  difference  absolute_difference  percentage_difference  \
# 58             0.75        0.00                 0.00                    0.0
# 15             0.50        0.00                 0.00                    0.0
# 74             0.50        0.00                 0.00                    0.0
# 1              0.25        0.00                 0.00                    0.0
# 27             0.50       -0.75                 0.75                  -60.0
#
#     scores_match              match_type  case_confidence  \
# 58          True             EXACT_MATCH             0.85
# 15          True             EXACT_MATCH             0.60
# 74          True             EXACT_MATCH             0.60
# 1           True             EXACT_MATCH             0.60
# 27         False  SIGNIFICANT_DIFFERENCE             0.85
#
#    publication_match_type
# 58      TITLE_AUTHOR_HIGH
# 15      TITLE_AUTHOR_HIGH
# 74      TITLE_AUTHOR_HIGH
# 1       TITLE_AUTHOR_HIGH
# 27      TITLE_AUTHOR_HIGH

# %%
f1_scores = evaluate_f1_between_manual_and_automatic(
    manual_df=manual_df,
    auto_extractions=eagle_ai_extractions
)
# Out:
# ================================================================================
# F1 EVALUATION REPORT
# ================================================================================
#
# Cases (manual vs automatic):
#   - Precision: 0.916
#   - Recall:    0.461
#   - F1:        0.613  (TP=76, FP=7, FN=89)
#
# Phenotype quality (High/Medium/Low):
#   - Micro P: 0.662, R: 0.618, F1: 0.639
#   - Macro F1: 0.601
#     - High   P: 0.639, R: 0.793, F1: 0.708
#     - Medium P: 0.462, R: 0.400, F1: 0.429
#     - Low    P: 0.818, R: 0.562, F1: 0.667
